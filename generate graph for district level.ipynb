# %% [markdown]
# # Graph Generation based on Exposure dataset

# %% [markdown]
# ### library imported

# %%
import matplotlib.pyplot as plt
import pandas as pd
import glob
import numpy as np
import os

# %%
# %matplotlib inline

# %% [markdown]
# ### combine dataframe for the dataset

# %%
#making dataframe for all combining datasets
path= r'C:\Users\GIC\Desktop\tek\Graphs\notebook\data\Exposure_tables\_csv'
df= pd.concat(map(pd.read_csv, glob.glob(os.path.join(path, '*.csv'))), axis=0)
# Out:
# C:\Users\GIC\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### removing dublicated values and reset the index

# %%
df.drop_duplicates(subset='JAMOAT_NAM', inplace=True)
df.reset_index()
# Out:
#      index  AGRI_AREA  AGRI_AREA.1  AGRI_AREA.2  AGRI_AREA.3  AGRI_AREA.4  \
# 0        0       2992         2992         2992         2992         2992
# 1        1       1980         1980         1980         1980         1980
# 2        3       1064         1064         1064         1064         1064
# 3        4      11576        11576        11576        11576        11576
# 4        5       7985         7985         7985         7985         7985
# ..     ...        ...          ...          ...          ...          ...
# 108      0      10636        10636        10636        10636        10636
# 109      1       5857         5857         5857         5857         5857
# 110      2       6566         6566         6566         6566         6566
# 111      3       4928         4928         4928         4928         4928
# 112      4      11905        11905        11905        11905        11905
#
#      AGRI_AREA.5  AGRI_AREA.6  AGRI_DR_10  AGRI_DR_11  ...  Shape_Length.4  \
# ...

# %% [markdown]
# ### Assigning the variable name accoring to district

# %%
# function for get the values from dataframe
def values(name):
    return df.groupby(district)[name].sum()

# %%
# variables from dataframe

jamoat = df['JAMOAT']
district = df['DISTRICT']

#EARTHQUAKE
e1 = values('BUIL_EQ_47')+values('BUIL_EQ_48')
e2 = values('BUIL_EQ_49')
e3 = values('BUIL_EQ_50')+values('BUIL_EQ_51')
e4 = values('PEOP_EQ_47')+values('PEOP_EQ_48')
e5 = values('PEOP_EQ_49')
e6 = values('PEOP_EQ_50')+values('PEOP_EQ_51')
e7 = values('AGRI_EQ_47')+values('AGRI_EQ_48')
e8 = values('AGRI_EQ_49')
e9 = values('AGRI_EQ_50')+values('AGRI_EQ_51')
e10 = values('ROAD_EQ_48')+values('ROAD_EQ_48')
e11 = values('ROAD_EQ_49')
e12 = values('ROAD_EQ_50')+values('ROAD_EQ_51')

#WINDSTROME
w1 = values('BUIL_WS_20')+values('BUIL_WS_21')
w2 = values('BUIL_WS_22')
w3 = values('BUIL_WS_23')+values('BUIL_WS_24')
w4 = values('PEOP_WS_20')+values('PEOP_WS_21')
w5 = values('PEOP_WS_22')
w6 = values('PEOP_WS_23')+values('PEOP_WS_24')
w7 = values('AGRI_WS_20')+values('AGRI_WS_21')
w8 = values('AGRI_WS_22')
w9 = values('AGRI_WS_23')+values('AGRI_WS_24')
w10 = values('ROAD_WS_20')+values('ROAD_WS_21')
w11 = values('ROAD_WS_22')
w12 = values('ROAD_WS_23')+values('ROAD_WS_24')

#FLOOD
f1 = values('BUIL_FL_20')+values('BUIL_FL_21')
f2 = values('BUIL_FL_22')
f3 = values('BUIL_FL_23')+values('BUIL_FL_24')
f4 = values('PEOP_FL_20')+values('PEOP_FL_21')
f5 = values('PEOP_FL_22')
f6 = values('PEOP_FL_23')+values('PEOP_FL_24')
f7 = values('AGRI_FL_20')+values('AGRI_FL_21')
f8 = values('AGRI_FL_22')
f9 = values('AGRI_FL_23')+values('AGRI_FL_24')
f10 = values('ROAD_FL_20')+values('ROAD_FL_21')
f11 = values('ROAD_FL_22')
f12 = values('ROAD_FL_23')+values('ROAD_FL_24')

#LANDSLIDE
l1 = values('BUIL_LS_50')+values('BUIL_LS_51')
l2 = values('BUIL_LS_52')
l3 = values('BUIL_LS_53')+values('BUIL_LS_54')
l4 = values('PEOP_LS_50')+values('PEOP_LS_51')
l5 = values('PEOP_LS_52')
l6 = values('PEOP_LS_53')+values('PEOP_LS_54')
l7 = values('AGRI_LS_50')+values('AGRI_LS_51')
l8 = values('AGRI_LS_52')
l9 = values('AGRI_LS_53')+values('AGRI_LS_54')
l10 = values('ROAD_LS_50')+values('ROAD_LS_51')
l11 = values('ROAD_LS_52')
l12 = values('ROAD_LS_53')+values('ROAD_LS_24')

#MUvalues(LOW
m1 = values('BUIL_MF_50')+values('BUIL_MF_51')
m2 = values('BUIL_MF_52')
m3 = values('BUIL_MF_53')+values('BUIL_MF_24')
m4 = values('PEOP_MF_50')+values('PEOP_MF_51')
m5 = values('PEOP_MF_52')
m6 = values('PEOP_MF_53')+values('PEOP_MF_54')
m7 = values('AGRI_MF_50')+values('AGRI_MF_51')
m8 = values('AGRI_MF_52')
m9 = values('AGRI_MF_53')+values('AGRI_MF_54')
m10 = values('ROAD_MF_50')+values('ROAD_MF_51')
m11 = values('ROAD_MF_52')
m12 = values('ROAD_MF_53')+values('ROAD_MF_54')

#SNOW AVALANCHE
s1 = values('BUIL_SA_50')+values('BUIL_SA_51')
s2 = values('BUIL_SA_52')
s3 = values('BUIL_SA_53')+values('BUIL_SA_54')
s4 = values('PEOP_SA_50')+values('PEOP_SA_51')
s5 = values('PEOP_SA_52')
s6 = values('PEOP_SA_53')+values('PEOP_SA_54')
s7 = values('AGRI_SA_50')+values('AGRI_SA_51')
s8 = values('AGRI_SA_52')
s9 = values('AGRI_SA_53')+values('AGRI_SA_54')
s10 = values('ROAD_SA_50')+values('ROAD_SA_51')
s11 = values('ROAD_SA_52')
s12 = values('ROAD_SA_53')+values('ROAD_SA_54')

#DROUGHT
d1 = values('BUIL_DR_50')+values('BUIL_DR_51')
d2 = values('BUIL_DR_52')
d3 = values('BUIL_DR_53')+values('BUIL_DR_54')
d4 = values('PEOP_DR_50')+values('PEOP_DR_51')
d5 = values('PEOP_DR_52')
d6 = values('PEOP_DR_53')+values('PEOP_DR_54')
d7 = values('AGRI_DR_50')+values('AGRI_DR_51')
d8 = values('AGRI_DR_52')
d9 = values('AGRI_DR_53')+values('AGRI_DR_54')
d10 = values('ROAD_DR_50')+values('ROAD_DR_51')
d11 = values('ROAD_DR_52')
d12 = values('ROAD_DR_53')+values('ROAD_DR_54')

# %% [markdown]
# ### Fuction for graph generation

# %%
def generateGraph(index):
    f = plt.figure(figsize=(11.69,8.27))
    #f.suptitle('This is the main title', fontsize=18) 
    
    # set width of bar
    barWidth = 0.25

    # for first graphset height of bar: BUILDINGS
    bars1 = [e1[index], w1[index], f1[index], l1[index], m1[index], s1[index]]
    bars2 = [e2[index], w2[index], f2[index], l2[index], m2[index], s2[index]]
    bars3 = [e3[index], w3[index], f3[index], l3[index], m3[index], s3[index]]

    # for second graphset height of bar: POPULATION
    bars4 = [e4[index], f4[index], l4[index], m4[index], s4[index]]
    bars5 = [e5[index], f5[index], l5[index], m5[index], s5[index]]
    bars6 = [e6[index], f6[index], l6[index], m6[index], s6[index]]

    # for third graphset height of bar: AGRICULTURE
    bars7 = [w7[index], f7[index], l7[index], m7[index], s7[index], d7[index]]
    bars8 = [w8[index], f8[index], l8[index], m8[index], s8[index], d8[index]]
    bars9 = [w9[index], f9[index], l9[index], m9[index], s9[index], d9[index]]

    # for fourth graphset height of bar: ROADS
    bars10 = [f10[index], l10[index], m10[index], s10[index]]
    bars11 = [f11[index], l11[index], m11[index], s11[index]]
    bars12 = [f12[index], l12[index], m12[index], s12[index]]

    # Set position of bar on X axis
    r1 = np.arange(len(bars1))
    r2 = [x + barWidth for x in r1]
    r3 = [x + barWidth for x in r2]
    
    # Set position of bar on X axis
    r4 = np.arange(len(bars4))
    r5 = [x + barWidth for x in r4]
    r6 = [x + barWidth for x in r5]
    
    # Set position of bar on X axis
    r7 = np.arange(len(bars7))
    r8 = [x + barWidth for x in r7]
    r9 = [x + barWidth for x in r8]
    
    # Set position of bar on X axis
    r10 = np.arange(len(bars10))
    r11 = [x + barWidth for x in r10]
    r12 = [x + barWidth for x in r11]

    # Make the plot
    plt.subplot(221)
    plt.title('Buiding exposure(number)')
    plt.bar(r1, bars1, color='#00b04f', width=barWidth, edgecolor='white', label='low')
    plt.bar(r2, bars2, color='#ffbf00', width=barWidth, edgecolor='white', label='medium')
    plt.bar(r3, bars3, color='#ff0000', width=barWidth, edgecolor='white', label='high')

    # Add xticks on the middle of the group bars
    # plt.xlabel('group', fontweight='bold')
    plt.xticks([r + barWidth for r in range(len(bars1))], ['EQ', 'WS', 'FL', 'LS', 'MF', 'SA'])


    # Make the plot
    plt.subplot(222)
    plt.title('Population(number)')
    plt.bar(r4, bars4, color='#00b04f', width=barWidth, edgecolor='white', label='low')
    plt.bar(r5, bars5, color='#ffbf00', width=barWidth, edgecolor='white', label='medium')
    plt.bar(r6, bars6, color='#ff0000', width=barWidth, edgecolor='white', label='high')

    # Add xticks on the middle of the group bars
    # plt.xlabel('group', fontweight='bold')
    plt.xticks([r + barWidth for r in range(len(bars4))], ['EQ', 'FL', 'LS', 'MF', 'SA'])

    # Make the plot
    plt.subplot(223)
    plt.title('Agricultural land exposed(hectares)')
    plt.bar(r7, bars7, color='#00b04f', width=barWidth, edgecolor='white', label='low')
    plt.bar(r8, bars8, color='#ffbf00', width=barWidth, edgecolor='white', label='medium')
    plt.bar(r9, bars9, color='#ff0000', width=barWidth, edgecolor='white', label='high')

    # Add xticks on the middle of the group bars
    # plt.xlabel('group', fontweight='bold')
    plt.xticks([r + barWidth for r in range(len(bars7))], ['WS', 'FL', 'LS', 'MF', 'SA', 'DR'])


    # Make the plot
    plt.subplot(224)
    plt.title('Road exposure(km)')
    plt.bar(r10, bars10, color='#00b04f', width=barWidth, edgecolor='white', label='low')
    plt.bar(r11, bars11, color='#ffbf00', width=barWidth, edgecolor='white', label='medium')
    plt.bar(r12, bars12, color='#ff0000', width=barWidth, edgecolor='white', label='high')

    # Add xticks on the middle of the group bars
    # plt.xlabel('group', fontweight='bold')
    plt.xticks([r + barWidth for r in range(len(bars10))], ['FL', 'LS', 'MF', 'SA'])

    l = df.DISTRICT.unique()
    # Create legend & Show graphic
    plt.tight_layout()
    plt.savefig('output/Bar_Chart-{}'.format(l[index]), figsize=(11.69,8.27))

# %%
for i in range(14):
    generateGraph(i)

# %% [markdown]
# # Verification of the data

# %%
values('BUIL_EQ_51')
# Out:
# DISTRICT
# Asht                  0
# Ayni                  0
# Bobojon_Ghafurov      0
# Devashtich            0
# Isfara                0
# Istaravshan           0
# Jabbor_Rasulov        0
# Konibodom             0
# Kuhistoni_Mastchoh    0
# Mastchoh              0
# Panjakent             0
# Shahriston            0
# Spitamen              0
# Zafarobod             0
# Name: BUIL_EQ_51, dtype: int64

# %%
values('BUIL_EQ_47')
# Out:
# DISTRICT
# Asht                  0
# Ayni                  0
# Bobojon_Ghafurov      0
# Devashtich            0
# Isfara                0
# Istaravshan           0
# Jabbor_Rasulov        0
# Konibodom             0
# Kuhistoni_Mastchoh    0
# Mastchoh              0
# Panjakent             0
# Shahriston            0
# Spitamen              0
# Zafarobod             0
# Name: BUIL_EQ_47, dtype: int64

# %% [markdown]
# ##### for legend

# %%
import matplotlib
from matplotlib.patches import Rectangle
from matplotlib.lines import Line2D

# %%
fig, ax = plt.subplots(1, figsize=(10,10))

#legend elements with styles
legend_elements = [Line2D([0], [0], marker='o', color='w', label="Low",markerfacecolor='#006737', markersize=45),
                  Line2D([0], [0], marker='o', color='w', label="Medium",markerfacecolor='#56B65F', markersize=45),
                  Line2D([0], [0], marker='o', color='w', label="High",markerfacecolor='#D9EF8C', markersize=45)]


# legend added to axis
ax.legend(handles=legend_elements, prop={'size': 45})
