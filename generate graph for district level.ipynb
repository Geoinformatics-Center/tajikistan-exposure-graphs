# %%
import matplotlib.pyplot as plt
import pandas as pd
import glob
import numpy as np
import os

# %%
# %matplotlib inline

# %%
#making dataframe for all combining datasets
path= r'C:\Users\GIC\Desktop\tek\Graphs\notebook\data\Exposure_tables\_csv'
df= pd.concat(map(pd.read_csv, glob.glob(os.path.join(path, '*.csv'))), axis=0)
# Out:
# C:\Users\GIC\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.drop_duplicates(subset='JAMOAT_NAM', inplace=True)
df.reset_index()
# Out:
#      index  AGRI_AREA  AGRI_AREA.1  AGRI_AREA.2  AGRI_AREA.3  AGRI_AREA.4  \
# 0        0       2992         2992         2992         2992         2992
# 1        1       1980         1980         1980         1980         1980
# 2        3       1064         1064         1064         1064         1064
# 3        4      11576        11576        11576        11576        11576
# 4        5       7985         7985         7985         7985         7985
# ..     ...        ...          ...          ...          ...          ...
# 108      0      10636        10636        10636        10636        10636
# 109      1       5857         5857         5857         5857         5857
# 110      2       6566         6566         6566         6566         6566
# 111      3       4928         4928         4928         4928         4928
# 112      4      11905        11905        11905        11905        11905
#
#      AGRI_AREA.5  AGRI_AREA.6  AGRI_DR_10  AGRI_DR_11  ...  Shape_Length.4  \
# ...

# %%
# function for get the values from dataframe
def values(name):
    return df.groupby(district)[name].sum()

# %%
# variables from dataframe

jamoat = df['JAMOAT']
district = df['DISTRICT']

#EARTHQUAKE
e1 = values('BUIL_EQ_48')
e2 = values('BUIL_EQ_49')
e3 = values('BUIL_EQ_50')
e4 = values('PEOP_EQ_48')
e5 = values('PEOP_EQ_49')
e6 = values('PEOP_EQ_50')
e7 = values('AGRI_EQ_48')
e8 = values('AGRI_EQ_49')
e9 = values('AGRI_EQ_50')
e10 = values('ROAD_EQ_48')
e11 = values('ROAD_EQ_49')
e12 = values('ROAD_EQ_50')

#WINDSTROME
w1 = values('BUIL_WS_21')
w2 = values('BUIL_WS_22')
w3 = values('BUIL_WS_23')
w4 = values('PEOP_WS_21')
w5 = values('PEOP_WS_22')
w6 = values('PEOP_WS_23')
w7 = values('AGRI_WS_21')
w8 = values('AGRI_WS_22')
w9 = values('AGRI_WS_23')
w10 = values('ROAD_WS_21')
w11 = values('ROAD_WS_22')
w12 = values('ROAD_WS_23')

#FLOOD
f1 = values('BUIL_FL_21')
f2 = values('BUIL_FL_22')
f3 = values('BUIL_FL_23')
f4 = values('PEOP_FL_21')
f5 = values('PEOP_FL_22')
f6 = values('PEOP_FL_23')
f7 = values('AGRI_FL_21')
f8 = values('AGRI_FL_22')
f9 = values('AGRI_FL_23')
f10 = values('ROAD_FL_21')
f11 = values('ROAD_FL_22')
f12 = values('ROAD_FL_23')

#LANDSLIDE
l1 = values('BUIL_LS_21')
l2 = values('BUIL_LS_22')
l3 = values('BUIL_LS_23')
l4 = values('PEOP_LS_21')
l5 = values('PEOP_LS_22')
l6 = values('PEOP_LS_23')
l7 = values('AGRI_LS_21')
l8 = values('AGRI_LS_22')
l9 = values('AGRI_LS_23')
l10 = values('ROAD_LS_21')
l11 = values('ROAD_LS_22')
l12 = values('ROAD_LS_23')

#MUvalues(LOW
m1 = values('BUIL_MF_21')
m2 = values('BUIL_MF_22')
m3 = values('BUIL_MF_23')
m4 = values('PEOP_MF_21')
m5 = values('PEOP_MF_22')
m6 = values('PEOP_MF_23')
m7 = values('AGRI_MF_21')
m8 = values('AGRI_MF_22')
m9 = values('AGRI_MF_23')
m10 = values('ROAD_MF_21')
m11 = values('ROAD_MF_22')
m12 = values('ROAD_MF_23')

#SNOW AVALANCHE
s1 = values('BUIL_SA_21')
s2 = values('BUIL_SA_22')
s3 = values('BUIL_SA_23')
s4 = values('PEOP_SA_21')
s5 = values('PEOP_SA_22')
s6 = values('PEOP_SA_23')
s7 = values('AGRI_SA_21')
s8 = values('AGRI_SA_22')
s9 = values('AGRI_SA_23')
s10 = values('ROAD_SA_21')
s11 = values('ROAD_SA_22')
s12 = values('ROAD_SA_23')

#DROUGHT
d1 = values('BUIL_DR_25')
d2 = values('BUIL_DR_26')
d3 = values('BUIL_DR_27')
d4 = values('PEOP_DR_25')
d5 = values('PEOP_DR_26')
d6 = values('PEOP_DR_27')
d7 = values('AGRI_DR_25')
d8 = values('AGRI_DR_26')
d9 = values('AGRI_DR_27')
d10 = values('ROAD_DR_25')
d11 = values('ROAD_DR_26')
d12 = values('ROAD_DR_27')

# %%
def generateGraph(index):
    f = plt.figure(figsize=(11.69,8.27))

    # set width of bar
    barWidth = 0.25

    # for first graphset height of bar
    bars1 = [e1[index], w1[index], f1[index], l1[index], m1[index], s1[index], d1[index]]
    bars2 = [e2[index], w2[index], f2[index], l2[index], m2[index], s2[index], d2[index]]
    bars3 = [e3[index], w3[index], f3[index], l3[index], m3[index], s3[index], d3[index]]

    # for second graphset height of bar
    bars4 = [e4[index], w4[index], f4[index], l4[index], m4[index], s4[index], d4[index]]
    bars5 = [e5[index], w5[index], f5[index], l5[index], m5[index], s5[index], d5[index]]
    bars6 = [e6[index], w6[index], f6[index], l6[index], m6[index], s6[index], d6[index]]

    # for third graphset height of bar
    bars7 = [e7[index], w7[index], f7[index], l7[index], m7[index], s7[index], d7[index]]
    bars8 = [e8[index], w8[index], f8[index], l8[index], m8[index], s8[index], d8[index]]
    bars9 = [e9[index], w9[index], f9[index], l9[index], m9[index], s9[index], d9[index]]

    # for third graphset height of bar
    bars10 = [e10[index], w10[index], f10[index], l10[index], m10[index], s10[index], d10[index]]
    bars11 = [e11[index], w11[index], f11[index], l11[index], m11[index], s11[index], d11[index]]
    bars12 = [e12[index], w12[index], f12[index], l12[index], m12[index], s12[index], d12[index]]

    # Set position of bar on X axis
    r1 = np.arange(len(bars1))
    r2 = [x + barWidth for x in r1]
    r3 = [x + barWidth for x in r2]

    # Make the plot
    plt.subplot(221)
    plt.title('Buiding exposure(number)')
    plt.bar(r1, bars1, color='#00b04f', width=barWidth, edgecolor='white', label='low')
    plt.bar(r2, bars2, color='#ffbf00', width=barWidth, edgecolor='white', label='medium')
    plt.bar(r3, bars3, color='#ff0000', width=barWidth, edgecolor='white', label='high')

    # Add xticks on the middle of the group bars
    # plt.xlabel('group', fontweight='bold')
    plt.xticks([r + barWidth for r in range(len(bars1))], ['EQ', 'WS', 'FL', 'LS', 'MF', 'SA', 'DR'])


        # Make the plot
    plt.subplot(222)
    plt.title('Population(number)')
    plt.bar(r1, bars4, color='#00b04f', width=barWidth, edgecolor='white', label='low')
    plt.bar(r2, bars5, color='#ffbf00', width=barWidth, edgecolor='white', label='medium')
    plt.bar(r3, bars6, color='#ff0000', width=barWidth, edgecolor='white', label='high')

    # Add xticks on the middle of the group bars
    # plt.xlabel('group', fontweight='bold')
    plt.xticks([r + barWidth for r in range(len(bars1))], ['EQ', 'WS', 'FL', 'LS', 'MF', 'SA', 'DR'])

    # Make the plot
    plt.subplot(223)
    plt.title('Agricultural land exposed(hectares)')
    plt.bar(r1, bars7, color='#00b04f', width=barWidth, edgecolor='white', label='low')
    plt.bar(r2, bars8, color='#ffbf00', width=barWidth, edgecolor='white', label='medium')
    plt.bar(r3, bars9, color='#ff0000', width=barWidth, edgecolor='white', label='high')

    # Add xticks on the middle of the group bars
    # plt.xlabel('group', fontweight='bold')
    plt.xticks([r + barWidth for r in range(len(bars1))], ['EQ', 'WS', 'FL', 'LS', 'MF', 'SA', 'DR'])


    # Make the plot
    plt.subplot(224)
    plt.title('Road exposure(km)')
    plt.bar(r1, bars10, color='#00b04f', width=barWidth, edgecolor='white', label='low')
    plt.bar(r2, bars11, color='#ffbf00', width=barWidth, edgecolor='white', label='medium')
    plt.bar(r3, bars12, color='#ff0000', width=barWidth, edgecolor='white', label='high')

    # Add xticks on the middle of the group bars
    # plt.xlabel('group', fontweight='bold')
    plt.xticks([r + barWidth for r in range(len(bars1))], ['EQ', 'WS', 'FL', 'LS', 'MF', 'SA', 'DR'])


    # Create legend & Show graphic
    plt.tight_layout()
    plt.savefig('figure {}'.format(index), figsize=(11.69,8.27))

# %%
generateGraph(0)

# %%
generateGraph(1)
